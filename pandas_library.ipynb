# %% [markdown]
# # PANDAS
# ##  Data Preprocesing in Machine Learning using Pandas
# ### Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
# ### 🎯 Pandas is an open source Python package that is most ividely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform thern into a standard and normalized format.
#
# ## 💡Preprocessing involves the following aspects:
# - missing values
# - data standarization
# - data normalization
# - data cleaning

# %%
import pandas as pd

# %%
data = { "cars": ["BMW", "Honda", "Suzuki", "Tata"],
        "models": ["2005", "2010", "2015", "2018"],
         "passenger": ["4", "5", "7", "10"]
        }
type(data)
# Out:
# dict

# %%
# convert dict ti dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     BMW   2005         4
# 1   Honda   2010         5
# 2  Suzuki   2015         7
# 3    Tata   2018        10

# %%
# save df to csv
df.to_csv("cars.csv")

# %%
# check the version of library
print(pd.__version__)
# Out:
# 2.2.2

# %%
# pandas series
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# create labes in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# access only the value of x
print(myvar["x"])
# Out:
# 1

# %%
# create a dataframe having two colums calories and duration
fatburn = { "calories" : ["100", "200", "300", "400", "500"],
           "duration" : ["30min", "45min", "50min", "60min", "65min"]
}
df = pd.DataFrame(fatburn)
print(df)
# Out:
#   calories duration
# 0      100    30min
# 1      200    45min
# 2      300    50min
# 3      400    60min

# %%
# locate only the first row in df
print(df.loc[3])
# Out:
# calories      400
# duration    60min
# Name: 3, dtype: object

# %%
print(df.loc[[0, 1]])
# Out:
#   calories duration
# 0      100    30min
# 1      200    45min

# %%
# indexing the dataframe with days name
dframe = pd.DataFrame(fatburn, index = ["sunday", "monday", "tuesday", "wednesday"])
print(dframe)
# Out:
#           calories duration
# sunday         100    30min
# monday         200    45min
# tuesday        300    50min
# wednesday      400    60min

# %% [markdown]
# # Regex
# 🎯 A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern. RegEx can be used to check if a string contains the specified search pattern.
#
# 👉 It has 5 different methods
# - findall : search for specific string pattern and return as a string
# - search : return if the search pattern is matched as an object
# - split : append matched string in a list
# - sub :
# - finditer

# %% [markdown]
# Data cleaning with pandas library
# Bad data can be:
# - empty cells
# - data in wrong formet
# - wrong data
# - duplicates

# %%
import pandas as pd
df = pd.read_csv("cars.csv")
df
# Out:
#    Unnamed: 0    cars  models  passenger
# 0           0     BMW    2005          4
# 1           1   Honda    2010          5
# 2           2  Suzuki    2015          7
# 3           3    Tata    2018         10

# %%
df = pd.read_csv("pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head(10)
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0
# 5        60  2020/12/06'    102       127     300.0
# 6        60  2020/12/07'    110       136     374.0
# 7       450  2020/12/08'    104       134     253.3
# 8        30  2020/12/09'    109       133     195.1
# 9        60  2020/12/10'     98       124     269.0

# %%
df.tail()
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
# clear null values | find and drop null values if any
df.dropna(inplace = True)
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df = pd.read_csv("pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
# fill null values
df.fillna(130, inplace = True)
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
#fill null values to a specific column only
df = pd.read_csv("pandas_dataset.csv")
df["Calories"].fillna(130, inplace = True)
df
# Out:
# <ipython-input-46-c42da123cf84>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...
